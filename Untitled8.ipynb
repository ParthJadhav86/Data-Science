# %% [markdown]
# <a href="https://colab.research.google.com/github/ParthJadhav86/dada/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/mobile_sales.csv')
df
# Out:
#                             TransactionID        Date MobileModel  \
# 0    79397f68-61ed-4ea8-bcb2-f918d4e6c05b  2024-01-06   direction
# 1    4f87d114-f522-4ead-93e3-f336402df6aa  2024-04-05       right
# 2    6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1  2024-02-13      summer
# 3    7da7de95-f772-4cc2-bce0-b0873f98233e  2024-04-17        keep
# 4    469044af-0d60-4d87-af66-c6603e844057  2024-06-02      option
# ..                                    ...         ...         ...
# 995  41f08915-addb-4966-8628-038c479c619a  2024-01-28   challenge
# 996  bcfa1912-5bd8-4894-900f-376fa48f022d  2024-07-13       least
# 997  e6839305-a177-4cda-aada-3ac1f49eeeec  2024-01-13       enjoy
# 998  12f7ac32-9063-4ae5-a122-385b06ba77af  2024-01-25        half
# 999  d3e82026-2084-40f2-8d5d-d2a94a198af9  2024-01-17        fill
#
#                           Brand    Price  UnitsSold  TotalRevenue  \
# 0                     Green Inc  1196.95         85      28002.80
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = {
    'TransactionID': [
        '79397f68-61ed-4ea8-bcb2-f918d4e6c05b', '4f87d114-f522-4ead-93e3-f336402df6aa', '6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1',
        '7da7de95-f772-4cc2-bce0-b0873f98233e', '469044af-0d60-4d87-af66-c6603e844057', '41f08915-addb-4966-8628-038c479c619a',
        'bcfa1912-5bd8-4894-900f-376fa48f022d', 'e6839305-a177-4cda-aada-3ac1f49eeeec', '12f7ac32-9063-4ae5-a122-385b06ba77af',
        'd3e82026-2084-40f2-8d5d-d2a94a198af9'
    ],
    'Date': [
        '2024-01-06', '2024-04-05', '2024-02-13', '2024-04-17', '2024-06-02', '2024-01-28', '2024-07-13', '2024-01-13', '2024-01-25',
        '2024-01-17'
    ],
    'TotalRevenue': [
        28002.80, 2378.82, 31322.56, 31159.75, 11523.36, 28865.70, 50471.42, 1381.82, 8557.32, 70739.76
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Convert 'Date' to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Sort DataFrame by date
df = df.sort_values('Date')

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['TotalRevenue'], marker='o', linestyle='-', color='b')
plt.title('Total Revenue Over Time')
plt.xlabel('Date')
plt.ylabel('Total Revenue')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()  # Adjust layout to make room for date labels

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'TransactionID': [
        '79397f68-61ed-4ea8-bcb2-f918d4e6c05b', '4f87d114-f522-4ead-93e3-f336402df6aa', '6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1',
        '7da7de95-f772-4cc2-bce0-b0873f98233e', '469044af-0d60-4d87-af66-c6603e844057', '41f08915-addb-4966-8628-038c479c619a',
        'bcfa1912-5bd8-4894-900f-376fa48f022d', 'e6839305-a177-4cda-aada-3ac1f49eeeec', '12f7ac32-9063-4ae5-a122-385b06ba77af',
        'd3e82026-2084-40f2-8d5d-d2a94a198af9'
    ],
    'Date': [
        '2024-01-06', '2024-04-05', '2024-02-13', '2024-04-17', '2024-06-02', '2024-01-28', '2024-07-13', '2024-01-13', '2024-01-25',
        '2024-01-17'
    ],
    'TotalRevenue': [
        28002.80, 2378.82, 31322.56, 31159.75, 11523.36, 28865.70, 50471.42, 1381.82, 8557.32, 70739.76
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Convert 'Date' to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Sort DataFrame by date
df = df.sort_values('Date')

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['TotalRevenue'], marker='o', linestyle='-', color='b', label='Total Revenue')

# Adding titles and labels
plt.title('Total Revenue Over Time')
plt.xlabel('Date')
plt.ylabel('Total Revenue')

# Adding grid and rotation for x-axis labels
plt.grid(True)
plt.xticks(rotation=45)

# Adding legend
plt.legend()

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'TransactionID': [
        '79397f68-61ed-4ea8-bcb2-f918d4e6c05b', '4f87d114-f522-4ead-93e3-f336402df6aa', '6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1',
        '7da7de95-f772-4cc2-bce0-b0873f98233e', '469044af-0d60-4d87-af66-c6603e844057', '41f08915-addb-4966-8628-038c479c619a',
        'bcfa1912-5bd8-4894-900f-376fa48f022d', 'e6839305-a177-4cda-aada-3ac1f49eeeec', '12f7ac32-9063-4ae5-a122-385b06ba77af',
        'd3e82026-2084-40f2-8d5d-d2a94a198af9'
    ],
    'Date': [
        '2024-01-06', '2024-04-05', '2024-02-13', '2024-04-17', '2024-06-02', '2024-01-28', '2024-07-13', '2024-01-13', '2024-01-25',
        '2024-01-17'
    ],
    'MobileModel': [
        'direction', 'right', 'summer', 'keep', 'option', 'challenge', 'least', 'enjoy', 'half', 'fill'
    ],
    'Brand': [
        'Green Inc', 'Thomas-Thompson', 'Sanchez-Williams', 'Greer and Sons', 'Brown and Sons', 'Brooks Ltd', 'Lang, Brown and Stone',
        'Atkinson, Moore and Nelson', 'Kim, Maxwell and Moore', 'Wallace LLC'
    ],
    'Price': [
        1196.95, 1010.34, 400.80, 338.60, 839.79, 1386.69, 1159.26, 544.31, 331.98, 973.97
    ],
    'UnitsSold': [
        85, 64, 95, 79, 41, 76, 59, 59, 84, 79
    ],
    'TotalRevenue': [
        28002.80, 2378.82, 31322.56, 31159.75, 11523.36, 28865.70, 50471.42, 1381.82, 8557.32, 70739.76
    ],
    'CustomerAge': [
        32, 55, 57, 46, 38, 39, 21, 26, 20, 44
    ],
    'CustomerGender': [
        'Female', 'Female', 'Male', 'Other', 'Male', 'Male', 'Other', 'Female', 'Male', 'Female'
    ],
    'Location': [
        'Port Erik', 'East Linda', 'East Angelicastad', 'East Kevin', 'New Lindaborough', 'Ronaldchester', 'West Jenniferport',
        'Barneschester', 'Jonesborough', 'Port Luis'
    ],
    'PaymentMethod': [
        'Online', 'Credit Card', 'Online', 'Cash', 'Online', 'Credit Card', 'Credit Card', 'Credit Card', 'Online', 'Credit Card'
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Create a count plot for the 'MobileModel' column
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='MobileModel', palette='viridis')

# Adding titles and labels
plt.title('Count of Each Mobile Model')
plt.xlabel('Mobile Model')
plt.ylabel('Count')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-d9889fdf900d>:53: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='MobileModel', palette='viridis')
